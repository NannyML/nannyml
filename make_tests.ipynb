# %%
import nannyml as nml
import numpy as np
import pandas as pd
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
# print nml path
print(nml.__file__)
# Out:
# /Users/carterblair/NannyMLdev/nannyml/nannyml/__init__.py

# %%
# suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# set pandas precision to full
pd.set_option('display.precision', 20)
np.set_printoptions(precision=20)

# %%
"""
1. 'chunk_size': 20000, 'normalize_confusion_matrix': None, business_cost_matrix: [[-1, 4], [8, -8]]
2. 'chunk_size': 20000, 'normalize_confusion_matrix': 'all', business_cost_matrix: [[-1, 4], [8, -8]]
3. 'chunk_size': 20000, 'normalize_confusion_matrix': 'true', business_cost_matrix: [[-1, 4], [8, -8]]
4. 'chunk_size': 20000, 'normalize_confusion_matrix': 'pred', business_cost_matrix: [[-1, 4], [8, -8]]
5. 'chunk_size': 20000, 'normalize_confusion_matrix': None, 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
6. 'chunk_size': 20000, 'normalize_confusion_matrix': 'all', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
7. 'chunk_size': 20000, 'normalize_confusion_matrix': 'true', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
8. 'chunk_size': 20000, 'normalize_confusion_matrix': 'pred', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
9. 'chunk_number': 4, 'normalize_confusion_matrix': None, business_cost_matrix: [[-1, 4], [8, -8]]
10. 'chunk_number': 4, 'normalize_confusion_matrix': 'all', business_cost_matrix: [[-1, 4], [8, -8]]
11. 'chunk_number': 4, 'normalize_confusion_matrix': 'true', business_cost_matrix: [[-1, 4], [8, -8]]
12. 'chunk_number': 4, 'normalize_confusion_matrix': 'pred', business_cost_matrix: [[-1, 4], [8, -8]]
13. 'chunk_number': 4, 'normalize_confusion_matrix': None, 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
14. 'chunk_number': 4, 'normalize_confusion_matrix': 'all', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
15. 'chunk_number': 4, 'normalize_confusion_matrix': 'true', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
16. 'chunk_number': 4, 'normalize_confusion_matrix': 'pred', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
17. 'chunk_period': 'Y', 'normalize_confusion_matrix': None, 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
18. 'chunk_period': 'Y', 'normalize_confusion_matrix': 'all', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
19. 'chunk_period': 'Y', 'normalize_confusion_matrix': 'true', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
20. 'chunk_period': 'Y', 'normalize_confusion_matrix': 'pred', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
21. 'normalize_confusion_matrix': None, business_cost_matrix: [[-1, 4], [8, -8]]
22. 'normalize_confusion_matrix': 'all', business_cost_matrix: [[-1, 4], [8, -8]]
23. 'normalize_confusion_matrix': 'true', business_cost_matrix: [[-1, 4], [8, -8]]
24. 'normalize_confusion_matrix': 'pred', business_cost_matrix: [[-1, 4], [8, -8]]
25. 'normalize_confusion_matrix': None, 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
26. 'normalize_confusion_matrix': 'all', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
27. 'normalize_confusion_matrix': 'true', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
28. 'normalize_confusion_matrix': 'pred', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
"""
# Out:
# "\n1. 'chunk_size': 20000, 'normalize_confusion_matrix': None, business_cost_matrix: [[-1, 4], [8, -8]]\n2. 'chunk_size': 20000, 'normalize_confusion_matrix': 'all', business_cost_matrix: [[-1, 4], [8, -8]]\n3. 'chunk_size': 20000, 'normalize_confusion_matrix': 'true', business_cost_matrix: [[-1, 4], [8, -8]]\n4. 'chunk_size': 20000, 'normalize_confusion_matrix': 'pred', business_cost_matrix: [[-1, 4], [8, -8]]\n5. 'chunk_size': 20000, 'normalize_confusion_matrix': None, 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]\n6. 'chunk_size': 20000, 'normalize_confusion_matrix': 'all', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]\n7. 'chunk_size': 20000, 'normalize_confusion_matrix': 'true', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]\n8. 'chunk_size': 20000, 'normalize_confusion_matrix': 'pred', 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]\n9. 'chunk_number'
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_size = 20000,
        normalize_confusion_matrix = None,
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_size\': 20000, \'normalize_confusion_matrix\': None, 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_size': 20000, 'normalize_confusion_matrix': None, 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:19999]', '[20000:49999]'],
# 					'estimated_roc_auc': [0.9690827692140925, 0.9627722759203226],
# 					'estimated_f1': [0.9479079222515973, 0.9278089207836576],
# 					'estimated_precision': [0.9436121782324026, 0.9197836255005452],
# 					'estimated_recall': [0.9522429574319092, 0.9359754933378336],
# 					'estimated_specificity': [0.9434949869571513, 0.9123732942949082],
# 					'estimated_accuracy': [0.9478536003143163, 0.9245926106862006],
# 					'estimated_true_positive': [9488.96406430504, 14537.180201036117],
# 					'estimated_true_negative': [9468.107941981285, 13200.5981195499],
# 					'estimated_false_positive': [567.0359356949585, 1267.8197989638852],
# 					'estimated_false_negative': [475.8920580187156, 994.4018804500995],
# 					'estimated_true_positive_cost': [-75911.71251444033, -116297.44160828894],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_size = 20000,
        normalize_confusion_matrix = 'all',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_size\': 20000, \'normalize_confusion_matrix\': \'all\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_size': 20000, 'normalize_confusion_matrix': 'all', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:19999]', '[20000:49999]'],
# 					'estimated_roc_auc': [0.9690827692140925, 0.9627722759203226],
# 					'estimated_f1': [0.9479079222515973, 0.9278089207836576],
# 					'estimated_precision': [0.9436121782324026, 0.9197836255005452],
# 					'estimated_recall': [0.9522429574319092, 0.9359754933378336],
# 					'estimated_specificity': [0.9434949869571513, 0.9123732942949082],
# 					'estimated_accuracy': [0.9478536003143163, 0.9245926106862006],
# 					'estimated_true_positive': [0.47444820321525205, 0.4845726733678706],
# 					'estimated_true_negative': [0.47340539709906426, 0.44001993731833],
# 					'estimated_false_positive': [0.02835179678474793, 0.04226065996546284],
# 					'estimated_false_negative': [0.02379460290093578, 0.03314672934833665],
# 					'estimated_true_positive_cost': [-75911.71251444033, -116297.44160828894],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_size = 20000,
        normalize_confusion_matrix = 'true',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_size\': 20000, \'normalize_confusion_matrix\': \'true\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_size': 20000, 'normalize_confusion_matrix': 'true', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:19999]', '[20000:49999]'],
# 					'estimated_roc_auc': [0.9690827692140925, 0.9627722759203226],
# 					'estimated_f1': [0.9479079222515973, 0.9278089207836576],
# 					'estimated_precision': [0.9436121782324026, 0.9197836255005452],
# 					'estimated_recall': [0.9522429574319092, 0.9359754933378336],
# 					'estimated_specificity': [0.9434949869571513, 0.9123732942949082],
# 					'estimated_accuracy': [0.9478536003143163, 0.9245926106862006],
# 					'estimated_true_positive': [0.9522429574319092, 0.9359754933378336],
# 					'estimated_true_negative': [0.9434949869571514, 0.9123732942949082],
# 					'estimated_false_positive': [0.05650501304284861, 0.08762670570509186],
# 					'estimated_false_negative': [0.04775704256809077, 0.06402450666216646],
# 					'estimated_true_positive_cost': [-75911.71251444033, -116297.44160828894],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_size = 20000,
        normalize_confusion_matrix = 'pred',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_size\': 20000, \'normalize_confusion_matrix\': \'pred\','business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_size': 20000, 'normalize_confusion_matrix': 'pred','business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:19999]', '[20000:49999]'],
# 					'estimated_roc_auc': [0.9690827692140925, 0.9627722759203226],
# 					'estimated_f1': [0.9479079222515973, 0.9278089207836576],
# 					'estimated_precision': [0.9436121782324026, 0.9197836255005452],
# 					'estimated_recall': [0.9522429574319092, 0.9359754933378336],
# 					'estimated_specificity': [0.9434949869571513, 0.9123732942949082],
# 					'estimated_accuracy': [0.9478536003143163, 0.9245926106862006],
# 					'estimated_true_positive': [0.9436121782324026, 0.9197836255005452],
# 					'estimated_true_negative': [0.952142793843653, 0.9299470320218318],
# 					'estimated_false_positive': [0.05638782176759731, 0.08021637449945493],
# 					'estimated_false_negative': [0.0478572061563471, 0.07005296797816835],
# 					'estimated_true_positive_cost': [-75911.71251444033, -116297.44160828894],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_size = 20000,
        timestamp_column_name='timestamp',
        normalize_confusion_matrix = None,
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_size\': 20000, \'normalize_confusion_matrix\': None, \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_size': 20000, 'normalize_confusion_matrix': None, 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:19999]', '[20000:49999]'],
# 					'estimated_roc_auc': [0.9690827692140925, 0.9627722759203226],
# 					'estimated_f1': [0.9479079222515973, 0.9278089207836576],
# 					'estimated_precision': [0.9436121782324026, 0.9197836255005452],
# 					'estimated_recall': [0.9522429574319092, 0.9359754933378336],
# 					'estimated_specificity': [0.9434949869571513, 0.9123732942949082],
# 					'estimated_accuracy': [0.9478536003143163, 0.9245926106862006],
# 					'estimated_true_positive': [9488.96406430504, 14537.180201036117],
# 					'estimated_true_negative': [9468.107941981285, 13200.5981195499],
# 					'estimated_false_positive': [567.0359356949585, 1267.8197989638852],
# 					'estimated_false_negative': [475.8920580187156, 994.4018804500995],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_size = 20000,
        timestamp_column_name='timestamp',
        normalize_confusion_matrix = 'all',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_size\': 20000, \'normalize_confusion_matrix\': \'all\', \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_size': 20000, 'normalize_confusion_matrix': 'all', 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:19999]', '[20000:49999]'],
# 					'estimated_roc_auc': [0.9690827692140925, 0.9627722759203226],
# 					'estimated_f1': [0.9479079222515973, 0.9278089207836576],
# 					'estimated_precision': [0.9436121782324026, 0.9197836255005452],
# 					'estimated_recall': [0.9522429574319092, 0.9359754933378336],
# 					'estimated_specificity': [0.9434949869571513, 0.9123732942949082],
# 					'estimated_accuracy': [0.9478536003143163, 0.9245926106862006],
# 					'estimated_true_positive': [0.47444820321525205, 0.4845726733678706],
# 					'estimated_true_negative': [0.47340539709906426, 0.44001993731833],
# 					'estimated_false_positive': [0.02835179678474793, 0.04226065996546284],
# 					'estimated_false_negative': [0.02379460290093578, 0.03314672934833665],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_size = 20000,
        timestamp_column_name='timestamp',
        normalize_confusion_matrix = 'true',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_size\': 20000, \'normalize_confusion_matrix\': \'true\', \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_size': 20000, 'normalize_confusion_matrix': 'true', 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:19999]', '[20000:49999]'],
# 					'estimated_roc_auc': [0.9690827692140925, 0.9627722759203226],
# 					'estimated_f1': [0.9479079222515973, 0.9278089207836576],
# 					'estimated_precision': [0.9436121782324026, 0.9197836255005452],
# 					'estimated_recall': [0.9522429574319092, 0.9359754933378336],
# 					'estimated_specificity': [0.9434949869571513, 0.9123732942949082],
# 					'estimated_accuracy': [0.9478536003143163, 0.9245926106862006],
# 					'estimated_true_positive': [0.9522429574319092, 0.9359754933378336],
# 					'estimated_true_negative': [0.9434949869571514, 0.9123732942949082],
# 					'estimated_false_positive': [0.05650501304284861, 0.08762670570509186],
# 					'estimated_false_negative': [0.04775704256809077, 0.06402450666216646],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_size = 20000,
        timestamp_column_name='timestamp',
        normalize_confusion_matrix = 'pred',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_size\': 20000, \'normalize_confusion_matrix\': \'pred\', \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_size': 20000, 'normalize_confusion_matrix': 'pred', 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:19999]', '[20000:49999]'],
# 					'estimated_roc_auc': [0.9690827692140925, 0.9627722759203226],
# 					'estimated_f1': [0.9479079222515973, 0.9278089207836576],
# 					'estimated_precision': [0.9436121782324026, 0.9197836255005452],
# 					'estimated_recall': [0.9522429574319092, 0.9359754933378336],
# 					'estimated_specificity': [0.9434949869571513, 0.9123732942949082],
# 					'estimated_accuracy': [0.9478536003143163, 0.9245926106862006],
# 					'estimated_true_positive': [0.9436121782324026, 0.9197836255005452],
# 					'estimated_true_negative': [0.952142793843653, 0.9299470320218318],
# 					'estimated_false_positive': [0.05638782176759731, 0.08021637449945493],
# 					'estimated_false_negative': [0.0478572061563471, 0.07005296797816835],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_number=4,
        normalize_confusion_matrix=None,
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_number\': 4, \'normalize_confusion_matrix\': None, 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_number': 4, 'normalize_confusion_matrix': None, 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:12499]', '[12500:24999]', '[25000:37499]', '[37500:49999]'],
# 					'estimated_roc_auc': [0.9690496133543502, 0.9690315182120458, 0.9607404611197395, 0.9611281635643135],
# 					'estimated_f1': [0.9478220802546018, 0.9483683062849226, 0.9235839411719146, 0.9239534478264141],
# 					'estimated_precision': [0.9432817252782693, 0.9446550044048795, 0.9145613073300847, 0.915231419744167],
# 					'estimated_recall': [0.9524063553647716, 0.9521109162736728, 0.9327863750020324, 0.932843314818147],
# 					'estimated_specificity': [0.9426505776503413, 0.9446298328855539, 0.9050174893945843, 0.9065202406788675],
# 					'estimated_accuracy': [0.9475319773956268, 0.9483565214666658, 0.9194997180834459, 0.920199809204049],
# 					'estimated_true_positive': [5956.8240951322705, 5928.6548076450235, 6080.918132437733, 6059.74723012613],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_number=4,
        normalize_confusion_matrix='all',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_number\': 4, \'normalize_confusion_matrix\': \'all\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_number': 4, 'normalize_confusion_matrix': 'all', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:12499]', '[12500:24999]', '[25000:37499]', '[37500:49999]'],
# 					'estimated_roc_auc': [0.9690496133543502, 0.9690315182120458, 0.9607404611197395, 0.9611281635643135],
# 					'estimated_f1': [0.9478220802546018, 0.9483683062849226, 0.9235839411719146, 0.9239534478264141],
# 					'estimated_precision': [0.9432817252782693, 0.9446550044048795, 0.9145613073300847, 0.915231419744167],
# 					'estimated_recall': [0.9524063553647716, 0.9521109162736728, 0.9327863750020324, 0.932843314818147],
# 					'estimated_specificity': [0.9426505776503413, 0.9446298328855539, 0.9050174893945843, 0.9065202406788675],
# 					'estimated_accuracy': [0.9475319773956268, 0.9483565214666658, 0.9194997180834459, 0.920199809204049],
# 					'estimated_true_positive': [0.4765459276105816, 0.4742923846116019, 0.4864734505950187, 0.48477977841009035],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_number=4,
        normalize_confusion_matrix='true',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_number\': 4, \'normalize_confusion_matrix\': \'true\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_number': 4, 'normalize_confusion_matrix': 'true', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:12499]', '[12500:24999]', '[25000:37499]', '[37500:49999]'],
# 					'estimated_roc_auc': [0.9690496133543502, 0.9690315182120458, 0.9607404611197395, 0.9611281635643135],
# 					'estimated_f1': [0.9478220802546018, 0.9483683062849226, 0.9235839411719146, 0.9239534478264141],
# 					'estimated_precision': [0.9432817252782693, 0.9446550044048795, 0.9145613073300847, 0.915231419744167],
# 					'estimated_recall': [0.9524063553647716, 0.9521109162736728, 0.9327863750020324, 0.932843314818147],
# 					'estimated_specificity': [0.9426505776503413, 0.9446298328855539, 0.9050174893945843, 0.9065202406788675],
# 					'estimated_accuracy': [0.9475319773956268, 0.9483565214666658, 0.9194997180834459, 0.920199809204049],
# 					'estimated_true_positive': [0.9524063553647716, 0.9521109162736727, 0.9327863750020323, 0.932843314818147],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_number=4,
        normalize_confusion_matrix='pred',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_number\': 4, \'normalize_confusion_matrix\': \'pred\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_number': 4, 'normalize_confusion_matrix': 'pred', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:12499]', '[12500:24999]', '[25000:37499]', '[37500:49999]'],
# 					'estimated_roc_auc': [0.9690496133543502, 0.9690315182120458, 0.9607404611197395, 0.9611281635643135],
# 					'estimated_f1': [0.9478220802546018, 0.9483683062849226, 0.9235839411719146, 0.9239534478264141],
# 					'estimated_precision': [0.9432817252782693, 0.9446550044048795, 0.9145613073300847, 0.915231419744167],
# 					'estimated_recall': [0.9524063553647716, 0.9521109162736728, 0.9327863750020324, 0.932843314818147],
# 					'estimated_specificity': [0.9426505776503413, 0.9446298328855539, 0.9050174893945843, 0.9065202406788675],
# 					'estimated_accuracy': [0.9475319773956268, 0.9483565214666658, 0.9194997180834459, 0.920199809204049],
# 					'estimated_true_positive': [0.9432817252782693, 0.9446550044048793, 0.9145613073300847, 0.9152314197441669],
# ...

# %%
#'chunk_number': 4, 'normalize_confusion_matrix': None, 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_number=4,
        timestamp_column_name='timestamp',
        normalize_confusion_matrix=None,
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_number\': 4, \'normalize_confusion_matrix\': None, \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_number': 4, 'normalize_confusion_matrix': None, 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:12499]', '[12500:24999]', '[25000:37499]', '[37500:49999]'],
# 					'estimated_roc_auc': [0.9690496133543502, 0.9690315182120458, 0.9607404611197395, 0.9611281635643135],
# 					'estimated_f1': [0.9478220802546018, 0.9483683062849226, 0.9235839411719146, 0.9239534478264141],
# 					'estimated_precision': [0.9432817252782693, 0.9446550044048795, 0.9145613073300847, 0.915231419744167],
# 					'estimated_recall': [0.9524063553647716, 0.9521109162736728, 0.9327863750020324, 0.932843314818147],
# 					'estimated_specificity': [0.9426505776503413, 0.9446298328855539, 0.9050174893945843, 0.9065202406788675],
# 					'estimated_accuracy': [0.9475319773956268, 0.9483565214666658, 0.9194997180834459, 0.920199809204049],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_number=4,
        timestamp_column_name='timestamp',
        normalize_confusion_matrix='all',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_number\': 4, \'normalize_confusion_matrix\': \'all\', \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_number': 4, 'normalize_confusion_matrix': 'all', 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:12499]', '[12500:24999]', '[25000:37499]', '[37500:49999]'],
# 					'estimated_roc_auc': [0.9690496133543502, 0.9690315182120458, 0.9607404611197395, 0.9611281635643135],
# 					'estimated_f1': [0.9478220802546018, 0.9483683062849226, 0.9235839411719146, 0.9239534478264141],
# 					'estimated_precision': [0.9432817252782693, 0.9446550044048795, 0.9145613073300847, 0.915231419744167],
# 					'estimated_recall': [0.9524063553647716, 0.9521109162736728, 0.9327863750020324, 0.932843314818147],
# 					'estimated_specificity': [0.9426505776503413, 0.9446298328855539, 0.9050174893945843, 0.9065202406788675],
# 					'estimated_accuracy': [0.9475319773956268, 0.9483565214666658, 0.9194997180834459, 0.920199809204049],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',  
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_number=4,
        timestamp_column_name='timestamp',
        normalize_confusion_matrix='true',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_number\': 4, \'normalize_confusion_matrix\': \'true\', \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_number': 4, 'normalize_confusion_matrix': 'true', 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:12499]', '[12500:24999]', '[25000:37499]', '[37500:49999]'],
# 					'estimated_roc_auc': [0.9690496133543502, 0.9690315182120458, 0.9607404611197395, 0.9611281635643135],
# 					'estimated_f1': [0.9478220802546018, 0.9483683062849226, 0.9235839411719146, 0.9239534478264141],
# 					'estimated_precision': [0.9432817252782693, 0.9446550044048795, 0.9145613073300847, 0.915231419744167],
# 					'estimated_recall': [0.9524063553647716, 0.9521109162736728, 0.9327863750020324, 0.932843314818147],
# 					'estimated_specificity': [0.9426505776503413, 0.9446298328855539, 0.9050174893945843, 0.9065202406788675],
# 					'estimated_accuracy': [0.9475319773956268, 0.9483565214666658, 0.9194997180834459, 0.920199809204049],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_number=4,
        timestamp_column_name='timestamp',
        normalize_confusion_matrix='pred',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_number\': 4, \'normalize_confusion_matrix\': \'pred\', \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_number': 4, 'normalize_confusion_matrix': 'pred', 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:12499]', '[12500:24999]', '[25000:37499]', '[37500:49999]'],
# 					'estimated_roc_auc': [0.9690496133543502, 0.9690315182120458, 0.9607404611197395, 0.9611281635643135],
# 					'estimated_f1': [0.9478220802546018, 0.9483683062849226, 0.9235839411719146, 0.9239534478264141],
# 					'estimated_precision': [0.9432817252782693, 0.9446550044048795, 0.9145613073300847, 0.915231419744167],
# 					'estimated_recall': [0.9524063553647716, 0.9521109162736728, 0.9327863750020324, 0.932843314818147],
# 					'estimated_specificity': [0.9426505776503413, 0.9446298328855539, 0.9050174893945843, 0.9065202406788675],
# 					'estimated_accuracy': [0.9475319773956268, 0.9483565214666658, 0.9194997180834459, 0.920199809204049],
# ...

# %%
#'chunk_period': 'Y', 'normalize_confusion_matrix': None, 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_period = 'Y',
        timestamp_column_name='timestamp',
        normalize_confusion_matrix=None,
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_period\': \'Y\', \'normalize_confusion_matrix\': None, \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_period': 'Y', 'normalize_confusion_matrix': None, 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['2017', '2018', '2019', '2020', '2021'],
# 					'estimated_roc_auc': [0.9686251180452822, 0.9691860189228905, 0.9643157928165687, 0.9610299125179039, 0.8947719335229752],
# 					'estimated_f1': [0.9486231864324036, 0.9477092734637503, 0.9315900332119164, 0.9240488520044474, 0.7926388251111386],
# 					'estimated_precision': [0.9425338528308135, 0.9440235151260787, 0.9244858823267199, 0.9151737753536913, 0.7100248791165871],
# 					'estimated_recall': [0.9547917131585199, 0.9514239252802291, 0.9388042123614001, 0.9330977499034733, 0.8970090514396291],
# 					'estimated_specificity': [0.937163050852636, 0.9454556899788352, 0.918667486315966, 0.9060337870230502, 0.8302703490347314],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_period = 'Y',
        timestamp_column_name='timestamp',
        normalize_confusion_matrix='all',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_period\': \'Y\', \'normalize_confusion_matrix\': \'all\', \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_period': 'Y', 'normalize_confusion_matrix': 'all', 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['2017', '2018', '2019', '2020', '2021'],
# 					'estimated_roc_auc': [0.9686251180452822, 0.9691860189228905, 0.9643157928165687, 0.9610299125179039, 0.8947719335229752],
# 					'estimated_f1': [0.9486231864324036, 0.9477092734637503, 0.9315900332119164, 0.9240488520044474, 0.7926388251111386],
# 					'estimated_precision': [0.9425338528308135, 0.9440235151260787, 0.9244858823267199, 0.9151737753536913, 0.7100248791165871],
# 					'estimated_recall': [0.9547917131585199, 0.9514239252802291, 0.9388042123614001, 0.9330977499034733, 0.8970090514396291],
# 					'estimated_specificity': [0.937163050852636, 0.9454556899788352, 0.918667486315966, 0.9060337870230502, 0.8302703490347314],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_period = 'Y',
        timestamp_column_name='timestamp',
        normalize_confusion_matrix='true',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_period\': \'Y\', \'normalize_confusion_matrix\': \'true\', \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_period': 'Y', 'normalize_confusion_matrix': 'true', 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['2017', '2018', '2019', '2020', '2021'],
# 					'estimated_roc_auc': [0.9686251180452822, 0.9691860189228905, 0.9643157928165687, 0.9610299125179039, 0.8947719335229752],
# 					'estimated_f1': [0.9486231864324036, 0.9477092734637503, 0.9315900332119164, 0.9240488520044474, 0.7926388251111386],
# 					'estimated_precision': [0.9425338528308135, 0.9440235151260787, 0.9244858823267199, 0.9151737753536913, 0.7100248791165871],
# 					'estimated_recall': [0.9547917131585199, 0.9514239252802291, 0.9388042123614001, 0.9330977499034733, 0.8970090514396291],
# 					'estimated_specificity': [0.937163050852636, 0.9454556899788352, 0.918667486315966, 0.9060337870230502, 0.8302703490347314],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        chunk_period = 'Y',
        timestamp_column_name='timestamp',
        normalize_confusion_matrix='pred',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'chunk_period\': \'Y\', \'normalize_confusion_matrix\': \'pred\', \'timestamp_column_name\': \'timestamp\','business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'chunk_period': 'Y', 'normalize_confusion_matrix': 'pred', 'timestamp_column_name': 'timestamp','business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['2017', '2018', '2019', '2020', '2021'],
# 					'estimated_roc_auc': [0.9686251180452822, 0.9691860189228905, 0.9643157928165687, 0.9610299125179039, 0.8947719335229752],
# 					'estimated_f1': [0.9486231864324036, 0.9477092734637503, 0.9315900332119164, 0.9240488520044474, 0.7926388251111386],
# 					'estimated_precision': [0.9425338528308135, 0.9440235151260787, 0.9244858823267199, 0.9151737753536913, 0.7100248791165871],
# 					'estimated_recall': [0.9547917131585199, 0.9514239252802291, 0.9388042123614001, 0.9330977499034733, 0.8970090514396291],
# 					'estimated_specificity': [0.937163050852636, 0.9454556899788352, 0.918667486315966, 0.9060337870230502, 0.8302703490347314],
# ...

# %%
#'normalize_confusion_matrix': None, business_cost_matrix: [[-1, 4], [8, -8]]
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        normalize_confusion_matrix=None,
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'normalize_confusion_matrix\': None, 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'normalize_confusion_matrix': None, 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:4999]', '[5000:9999]', '[10000:14999]', '[15000:19999]', '[20000:24999]', '[25000:29999]', '[30000:34999]', '[35000:39999]', '[40000:44999]', '[45000:49999]'],
# 					'estimated_roc_auc': [0.9686306166809373, 0.9690438435474089, 0.9694438261961335, 0.9690472634498744, 0.9688726952274674, 0.960478016244988, 0.9611336210051199, 0.9605358219511105, 0.9618691204348024, 0.9605366452565602],
# 					'estimated_f1': [0.948555321454138, 0.9465779465209089, 0.9488069354531159, 0.9476546805658866, 0.9488338110572719, 0.9232325655782327, 0.923595783273164, 0.9229020961475524, 0.9241722368115827, 0.9249152193013231],
# 					'estimated_precision': [0.9425440716307568, 0.9431073537123396, 0.9442277523749669, 0.9446336452028188, 0.9453707449594683, 0.9148732952385749, 0.9143489884377147, 0.9133821290777778, 0.9173539177641505, 0.9145726617897999],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        normalize_confusion_matrix='all',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'normalize_confusion_matrix\': \'all\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'normalize_confusion_matrix': 'all', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:4999]', '[5000:9999]', '[10000:14999]', '[15000:19999]', '[20000:24999]', '[25000:29999]', '[30000:34999]', '[35000:39999]', '[40000:44999]', '[45000:49999]'],
# 					'estimated_roc_auc': [0.9686306166809373, 0.9690438435474089, 0.9694438261961335, 0.9690472634498744, 0.9688726952274674, 0.960478016244988, 0.9611336210051199, 0.9605358219511105, 0.9618691204348024, 0.9605366452565602],
# 					'estimated_f1': [0.948555321454138, 0.9465779465209089, 0.9488069354531159, 0.9476546805658866, 0.9488338110572719, 0.9232325655782327, 0.923595783273164, 0.9229020961475524, 0.9241722368115827, 0.9249152193013231],
# 					'estimated_precision': [0.9425440716307568, 0.9431073537123396, 0.9442277523749669, 0.9446336452028188, 0.9453707449594683, 0.9148732952385749, 0.9143489884377147, 0.9133821290777778, 0.9173539177641505, 0.9145726617897999],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        normalize_confusion_matrix='true',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'normalize_confusion_matrix\': \'true\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'normalize_confusion_matrix': 'true', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:4999]', '[5000:9999]', '[10000:14999]', '[15000:19999]', '[20000:24999]', '[25000:29999]', '[30000:34999]', '[35000:39999]', '[40000:44999]', '[45000:49999]'],
# 					'estimated_roc_auc': [0.9686306166809373, 0.9690438435474089, 0.9694438261961335, 0.9690472634498744, 0.9688726952274674, 0.960478016244988, 0.9611336210051199, 0.9605358219511105, 0.9618691204348024, 0.9605366452565602],
# 					'estimated_f1': [0.948555321454138, 0.9465779465209089, 0.9488069354531159, 0.9476546805658866, 0.9488338110572719, 0.9232325655782327, 0.923595783273164, 0.9229020961475524, 0.9241722368115827, 0.9249152193013231],
# 					'estimated_precision': [0.9425440716307568, 0.9431073537123396, 0.9442277523749669, 0.9446336452028188, 0.9453707449594683, 0.9148732952385749, 0.9143489884377147, 0.9133821290777778, 0.9173539177641505, 0.9145726617897999],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        normalize_confusion_matrix='pred',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'normalize_confusion_matrix\': \'pred\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'normalize_confusion_matrix': 'pred', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:4999]', '[5000:9999]', '[10000:14999]', '[15000:19999]', '[20000:24999]', '[25000:29999]', '[30000:34999]', '[35000:39999]', '[40000:44999]', '[45000:49999]'],
# 					'estimated_roc_auc': [0.9686306166809373, 0.9690438435474089, 0.9694438261961335, 0.9690472634498744, 0.9688726952274674, 0.960478016244988, 0.9611336210051199, 0.9605358219511105, 0.9618691204348024, 0.9605366452565602],
# 					'estimated_f1': [0.948555321454138, 0.9465779465209089, 0.9488069354531159, 0.9476546805658866, 0.9488338110572719, 0.9232325655782327, 0.923595783273164, 0.9229020961475524, 0.9241722368115827, 0.9249152193013231],
# 					'estimated_precision': [0.9425440716307568, 0.9431073537123396, 0.9442277523749669, 0.9446336452028188, 0.9453707449594683, 0.9148732952385749, 0.9143489884377147, 0.9133821290777778, 0.9173539177641505, 0.9145726617897999],
# ...

# %%
# 'normalize_confusion_matrix': None, 'timestamp_column_name': 'timestamp', business_cost_matrix: [[-1, 4], [8, -8]]
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        normalize_confusion_matrix=None,
        timestamp_column_name='timestamp',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'normalize_confusion_matrix\': None, \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'normalize_confusion_matrix': None, 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:4999]', '[5000:9999]', '[10000:14999]', '[15000:19999]', '[20000:24999]', '[25000:29999]', '[30000:34999]', '[35000:39999]', '[40000:44999]', '[45000:49999]'],
# 					'estimated_roc_auc': [0.9686306166809373, 0.9690438435474089, 0.9694438261961335, 0.9690472634498744, 0.9688726952274674, 0.960478016244988, 0.9611336210051199, 0.9605358219511105, 0.9618691204348024, 0.9605366452565602],
# 					'estimated_f1': [0.948555321454138, 0.9465779465209089, 0.9488069354531159, 0.9476546805658866, 0.9488338110572719, 0.9232325655782327, 0.923595783273164, 0.9229020961475524, 0.9241722368115827, 0.9249152193013231],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        normalize_confusion_matrix='all',
        timestamp_column_name='timestamp',
        business_cost_matrix = [[-1, 4], [8, -8]],
    ).fit(ref_df)   
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'normalize_confusion_matrix\': \'all\', \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'normalize_confusion_matrix': 'all', 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:4999]', '[5000:9999]', '[10000:14999]', '[15000:19999]', '[20000:24999]', '[25000:29999]', '[30000:34999]', '[35000:39999]', '[40000:44999]', '[45000:49999]'],
# 					'estimated_roc_auc': [0.9686306166809373, 0.9690438435474089, 0.9694438261961335, 0.9690472634498744, 0.9688726952274674, 0.960478016244988, 0.9611336210051199, 0.9605358219511105, 0.9618691204348024, 0.9605366452565602],
# 					'estimated_f1': [0.948555321454138, 0.9465779465209089, 0.9488069354531159, 0.9476546805658866, 0.9488338110572719, 0.9232325655782327, 0.923595783273164, 0.9229020961475524, 0.9241722368115827, 0.9249152193013231],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        normalize_confusion_matrix='true',
        timestamp_column_name='timestamp',
        business_cost_matrix = [[-1, 4], [8, -8]],
        ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'normalize_confusion_matrix\': \'true\', \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'normalize_confusion_matrix': 'true', 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:4999]', '[5000:9999]', '[10000:14999]', '[15000:19999]', '[20000:24999]', '[25000:29999]', '[30000:34999]', '[35000:39999]', '[40000:44999]', '[45000:49999]'],
# 					'estimated_roc_auc': [0.9686306166809373, 0.9690438435474089, 0.9694438261961335, 0.9690472634498744, 0.9688726952274674, 0.960478016244988, 0.9611336210051199, 0.9605358219511105, 0.9618691204348024, 0.9605366452565602],
# 					'estimated_f1': [0.948555321454138, 0.9465779465209089, 0.9488069354531159, 0.9476546805658866, 0.9488338110572719, 0.9232325655782327, 0.923595783273164, 0.9229020961475524, 0.9241722368115827, 0.9249152193013231],
# ...

# %%
ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()
cbpe = nml.CBPE(
        y_pred_proba='y_pred_proba',
        y_pred='y_pred',
        y_true='work_home_actual',
        problem_type='classification_binary',
        metrics=['roc_auc', 'f1', 'precision', 'recall', 'specificity', 'accuracy', 'confusion_matrix', 'business_cost'],
        normalize_confusion_matrix='pred',
        timestamp_column_name='timestamp',
        business_cost_matrix = [[-1, 4], [8, -8]],
        ).fit(ref_df)
result = cbpe.estimate(ana_df)
data = result.filter(period = 'analysis').to_df()
print("(")
print("\t\t\t{\'normalize_confusion_matrix\': \'pred\', \'timestamp_column_name\': \'timestamp\', 'business_cost_matrix': [[-1, 4], [8, -8]]},")
print("\t\t\tpd.DataFrame(")
print("\t\t\t\t{")
print(f"\t\t\t\t\t'key\': {[x for x in data['chunk']['key'].values]},")
print(f"\t\t\t\t\t'estimated_roc_auc\': {[x for x in data['roc_auc']['value'].values]},")
print(f"\t\t\t\t\t'estimated_f1\': {[x for x in data['f1']['value'].values]},")
print(f"\t\t\t\t\t'estimated_precision\': {[x for x in data['precision']['value'].values]},")
print(f"\t\t\t\t\t'estimated_recall\': {[x for x in data['recall']['value'].values]},")
print(f"\t\t\t\t\t'estimated_specificity\': {[x for x in data['specificity']['value'].values]},")
print(f"\t\t\t\t\t'estimated_accuracy\': {[x for x in data['accuracy']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive\': {[x for x in data['true_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative\': {[x for x in data['true_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive\': {[x for x in data['false_positive']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative\': {[x for x in data['false_negative']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_positive_cost\': {[x for x in data['true_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_true_negative_cost\': {[x for x in data['true_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_positive_cost\': {[x for x in data['false_positive_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_false_negative_cost\': {[x for x in data['false_negative_cost']['value'].values]},")
print(f"\t\t\t\t\t'estimated_total_cost\': {[x for x in data['total_cost']['value'].values]},")
print("\t\t\t\t}")
print("\t\t\t)")
print("\t\t),")
# Out:
# (
# 			{'normalize_confusion_matrix': 'pred', 'timestamp_column_name': 'timestamp', 'business_cost_matrix': [[-1, 4], [8, -8]]},
# 			pd.DataFrame(
# 				{
# 					'key': ['[0:4999]', '[5000:9999]', '[10000:14999]', '[15000:19999]', '[20000:24999]', '[25000:29999]', '[30000:34999]', '[35000:39999]', '[40000:44999]', '[45000:49999]'],
# 					'estimated_roc_auc': [0.9686306166809373, 0.9690438435474089, 0.9694438261961335, 0.9690472634498744, 0.9688726952274674, 0.960478016244988, 0.9611336210051199, 0.9605358219511105, 0.9618691204348024, 0.9605366452565602],
# 					'estimated_f1': [0.948555321454138, 0.9465779465209089, 0.9488069354531159, 0.9476546805658866, 0.9488338110572719, 0.9232325655782327, 0.923595783273164, 0.9229020961475524, 0.9241722368115827, 0.9249152193013231],
# ...
