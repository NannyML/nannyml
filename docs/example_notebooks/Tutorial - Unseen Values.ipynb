# %%
import nannyml as nml
from IPython.display import display

reference, analysis, analysis_targets = nml.load_titanic_dataset()
display(reference.head())
# Out:
# /var/home/nannyml/.conda/envs/poetry/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked boat  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S  NaN
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C    4
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  NaN
# 3  female  35.0      1      0            113803  53.1000  C123        S    D
# 4    male  35.0      0      0            373450   8.0500   NaN        S  NaN
#
#    body                                          home.dest  Survived
# 0   NaN                                  Bridgerule, Devon         0
# 1   NaN                                       New York, NY         1
# 2   NaN                                                NaN         1
# 3   NaN                                       Scituate, MA         1
# 4   NaN  Lower Clapton, Middlesex or Erdington, Birmingham         0

# %%
from docs.utils import print_multi_index_markdown
print_multi_index_markdown(reference.head())
# Out:
# +----+---------------+----------+-----------------------------------------------------+--------+-------+---------+---------+------------------+---------+---------+------------+--------+--------+---------------------------------------------------+------------+
# |    | PassengerId   | Pclass   | Name                                                | Sex    | Age   | SibSp   | Parch   | Ticket           | Fare    | Cabin   | Embarked   | boat   | body   | home.dest                                         | Survived   |
# +====+===============+==========+=====================================================+========+=======+=========+=========+==================+=========+=========+============+========+========+===================================================+============+
# | 0  | 1             | 3        | Braund, Mr. Owen Harris                             | male   | 22    | 1       | 0       | A/5 21171        | 7.25    | nan     | S          | nan    | nan    | Bridgerule, Devon                                 | 0          |
# +----+---------------+----------+-----------------------------------------------------+--------+-------+---------+---------+------------------+---------+---------+------------+--------+--------+---------------------------------------------------+------------+
# | 1  | 2             | 1        | Cumings, Mrs. John Bradley (Florence Briggs Thayer) | female | 38    | 1       | 0       | PC 17599         | 71.2833 | C85     | C          | 4      | nan    | New York, NY                                      | 1          |
# +----+---------------+----------+-----------------------------------------------------+--------+-------+---------+---------+------------------+---------+---------+------------+--------+--------+---------------------------------------------------+------------+
# | 2  | 3             | 3        | Heikkinen, Miss. Laina                              | female | 26    | 0       | 0       | STON/O2. 3101282 | 7.925   | nan     | S          | nan    | nan    | nan                                               | 1          |
# +----+---------------+----------+-----------------------------------------------------+--------+-------+---------+---------+------------------+---------+---------+------------+--------+--------+---------------------------------------------------+------------+
# | 3  | 4             | 1        | Futrelle, Mrs. Jacques Heath (Lily May Peel)        | female | 35    | 1       | 0       | 113803           | 53.1    | C123    | S          | D      | nan    | Scituate, MA                                      | 1          |
# +----+---------------+----------+-----------------------------------------------------+--------+-------+---------+---------+------------------+---------+---------+------------+--------+--------+---------------------------------------------------+------------+
# | 4  | 5             | 3        | Allen, Mr. William Henry                            | male   | 35    | 0       | 0       | 373450           | 8.05    | nan     | S          | nan    | nan    | Lower Clapton, Middlesex or Erdington, Birmingham | 0          |
# +----+---------------+----------+-----------------------------------------------------+--------+-------+---------+---------+------------------+---------+---------+------------+--------+--------+---------------------------------------------------+------------+

# %%
selected_columns = [
    'Sex', 'Ticket', 'Cabin', 'Embarked',
]
calc = nml.UnseenValuesCalculator(
    column_names=selected_columns,
)

# %%
calc.fit(reference)
results = calc.calculate(analysis)
display(results.filter(period='all').to_df())
# Out:
#         chunk                                                        \
#           key chunk_index start_index end_index start_date end_date
# 0      [0:88]           0           0        88       None     None
# 1    [89:177]           1          89       177       None     None
# 2   [178:266]           2         178       266       None     None
# 3   [267:355]           3         267       355       None     None
# 4   [356:444]           4         356       444       None     None
# 5   [445:533]           5         445       533       None     None
# 6   [534:622]           6         534       622       None     None
# 7   [623:711]           7         623       711       None     None
# 8   [712:800]           8         712       800       None     None
# 9   [801:890]           9         801       890       None     None
# 10     [0:40]           0           0        40       None     None
# 11    [41:81]           1          41        81       None     None
# 12   [82:122]           2          82       122       None     None
# 13  [123:163]           3         123       163       None     None
# 14  [164:204]           4         164       204       None     None
# 15  [205:245]           5         205       245       None     None
# 16  [246:286]           6         246       286       None     None
# 17  [287:327]           7         287       327       None     None
# 18  [328:368]           8         328       368       None     None
# 19  [369:417]           9         369       417       None     None
#
#                 Sex                                  ...          Ticket  \
#        period value upper_threshold lower_threshold  ... lower_threshold
# 0   reference   0.0               0            None  ...            None
# 1   reference   0.0               0            None  ...            None
# 2   reference   0.0               0            None  ...            None
# 3   reference   0.0               0            None  ...            None
# 4   reference   0.0               0            None  ...            None
# 5   reference   0.0               0            None  ...            None
# 6   reference   0.0               0            None  ...            None
# 7   reference   0.0               0            None  ...            None
# 8   reference   0.0               0            None  ...            None
# 9   reference   0.0               0            None  ...            None
# 10   analysis   0.0               0            None  ...            None
# 11   analysis   0.0               0            None  ...            None
# 12   analysis   0.0               0            None  ...            None
# 13   analysis   0.0               0            None  ...            None
# 14   analysis   0.0               0            None  ...            None
# 15   analysis   0.0               0            None  ...            None
# 16   analysis   0.0               0            None  ...            None
# 17   analysis   0.0               0            None  ...            None
# 18   analysis   0.0               0            None  ...            None
# 19   analysis   0.0               0            None  ...            None
#
#               Cabin                                        Embarked  \
#     alert     value upper_threshold lower_threshold  alert    value
# 0   False  0.000000               0            None  False      0.0
# 1   False  0.000000               0            None  False      0.0
# 2   False  0.000000               0            None  False      0.0
# 3   False  0.000000               0            None  False      0.0
# 4   False  0.000000               0            None  False      0.0
# 5   False  0.000000               0            None  False      0.0
# 6   False  0.000000               0            None  False      0.0
# 7   False  0.000000               0            None  False      0.0
# 8   False  0.000000               0            None  False      0.0
# 9   False  0.000000               0            None  False      0.0
# 10   True  0.073171               0            None   True      0.0
# 11   True  0.219512               0            None   True      0.0
# 12   True  0.146341               0            None   True      0.0
# 13   True  0.073171               0            None   True      0.0
# 14   True  0.097561               0            None   True      0.0
# 15   True  0.073171               0            None   True      0.0
# 16   True  0.073171               0            None   True      0.0
# 17   True  0.097561               0            None   True      0.0
# 18   True  0.048780               0            None   True      0.0
# 19   True  0.183673               0            None   True      0.0
#
#
#    upper_threshold lower_threshold  alert
# 0                0            None  False
# 1                0            None  False
# 2                0            None  False
# 3                0            None  False
# 4                0            None  False
# 5                0            None  False
# 6                0            None  False
# 7                0            None  False
# 8                0            None  False
# 9                0            None  False
# 10               0            None  False
# 11               0            None  False
# 12               0            None  False
# 13               0            None  False
# 14               0            None  False
# 15               0            None  False
# 16               0            None  False
# 17               0            None  False
# 18               0            None  False
# 19               0            None  False
#
# [20 rows x 23 columns]

# %%
print_multi_index_markdown(results.filter(period='all').to_df())
# Out:
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# |    | | chunk   |                 |                 |               |                |              |            | | Sex     |                     |                     |           | | Ticket   |                     |                     |           | | Cabin   |                     |                     |           | | Embarked   |                     |                     |           |
# |    | | key     | | chunk_index   | | start_index   | | end_index   | | start_date   | | end_date   | | period   | | value   | | upper_threshold   | | lower_threshold   | | alert   | | value    | | upper_threshold   | | lower_threshold   | | alert   | | value   | | upper_threshold   | | lower_threshold   | | alert   | | value      | | upper_threshold   | | lower_threshold   | | alert   |
# +====+===========+=================+=================+===============+================+==============+============+===========+=====================+=====================+===========+============+=====================+=====================+===========+===========+=====================+=====================+===========+==============+=====================+=====================+===========+
# | 0  | [0:88]    | 0               | 0               | 88            |                |              | reference  | 0         | 0                   |                     | False     | 0          | 0                   |                     | False     | 0         | 0                   |                     | False     | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 1  | [89:177]  | 1               | 89              | 177           |                |              | reference  | 0         | 0                   |                     | False     | 0          | 0                   |                     | False     | 0         | 0                   |                     | False     | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 2  | [178:266] | 2               | 178             | 266           |                |              | reference  | 0         | 0                   |                     | False     | 0          | 0                   |                     | False     | 0         | 0                   |                     | False     | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 3  | [267:355] | 3               | 267             | 355           |                |              | reference  | 0         | 0                   |                     | False     | 0          | 0                   |                     | False     | 0         | 0                   |                     | False     | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 4  | [356:444] | 4               | 356             | 444           |                |              | reference  | 0         | 0                   |                     | False     | 0          | 0                   |                     | False     | 0         | 0                   |                     | False     | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 5  | [445:533] | 5               | 445             | 533           |                |              | reference  | 0         | 0                   |                     | False     | 0          | 0                   |                     | False     | 0         | 0                   |                     | False     | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 6  | [534:622] | 6               | 534             | 622           |                |              | reference  | 0         | 0                   |                     | False     | 0          | 0                   |                     | False     | 0         | 0                   |                     | False     | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 7  | [623:711] | 7               | 623             | 711           |                |              | reference  | 0         | 0                   |                     | False     | 0          | 0                   |                     | False     | 0         | 0                   |                     | False     | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 8  | [712:800] | 8               | 712             | 800           |                |              | reference  | 0         | 0                   |                     | False     | 0          | 0                   |                     | False     | 0         | 0                   |                     | False     | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 9  | [801:890] | 9               | 801             | 890           |                |              | reference  | 0         | 0                   |                     | False     | 0          | 0                   |                     | False     | 0         | 0                   |                     | False     | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 10 | [0:40]    | 0               | 0               | 40            |                |              | analysis   | 0         | 0                   |                     | False     | 0.609756   | 0                   |                     | True      | 0.0731707 | 0                   |                     | True      | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 11 | [41:81]   | 1               | 41              | 81            |                |              | analysis   | 0         | 0                   |                     | False     | 0.634146   | 0                   |                     | True      | 0.219512  | 0                   |                     | True      | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 12 | [82:122]  | 2               | 82              | 122           |                |              | analysis   | 0         | 0                   |                     | False     | 0.731707   | 0                   |                     | True      | 0.146341  | 0                   |                     | True      | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 13 | [123:163] | 3               | 123             | 163           |                |              | analysis   | 0         | 0                   |                     | False     | 0.634146   | 0                   |                     | True      | 0.0731707 | 0                   |                     | True      | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 14 | [164:204] | 4               | 164             | 204           |                |              | analysis   | 0         | 0                   |                     | False     | 0.536585   | 0                   |                     | True      | 0.097561  | 0                   |                     | True      | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 15 | [205:245] | 5               | 205             | 245           |                |              | analysis   | 0         | 0                   |                     | False     | 0.658537   | 0                   |                     | True      | 0.0731707 | 0                   |                     | True      | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 16 | [246:286] | 6               | 246             | 286           |                |              | analysis   | 0         | 0                   |                     | False     | 0.756098   | 0                   |                     | True      | 0.0731707 | 0                   |                     | True      | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 17 | [287:327] | 7               | 287             | 327           |                |              | analysis   | 0         | 0                   |                     | False     | 0.707317   | 0                   |                     | True      | 0.097561  | 0                   |                     | True      | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 18 | [328:368] | 8               | 328             | 368           |                |              | analysis   | 0         | 0                   |                     | False     | 0.536585   | 0                   |                     | True      | 0.0487805 | 0                   |                     | True      | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+
# | 19 | [369:417] | 9               | 369             | 417           |                |              | analysis   | 0         | 0                   |                     | False     | 0.571429   | 0                   |                     | True      | 0.183673  | 0                   |                     | True      | 0            | 0                   |                     | False     |
# +----+-----------+-----------------+-----------------+---------------+----------------+--------------+------------+-----------+---------------------+---------------------+-----------+------------+---------------------+---------------------+-----------+-----------+---------------------+---------------------+-----------+--------------+---------------------+---------------------+-----------+

# %%
for column_name in results.column_names:
    results.filter(column_names=column_name).plot().show()

# %%
for column_name in results.column_names:
    results.filter(column_names=column_name).plot().write_image(
        f"../_static/tutorials/data_quality/unseen-titanic-{column_name}.svg"
    )
