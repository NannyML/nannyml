# %%
import nannyml as nml
import pandas as pd
from IPython.display import display

# %%
from docs.utils import print_some_of_the_columns_only_markdown, print_table

# %%
reference_df, analysis_df, _ = nml.load_us_census_ma_employment_data()
display(reference_df.head())
display(analysis_df.head())
# Out:
#    AGEP SCHL MAR RELP DIS ESP CIT MIG MIL ANC NATIVITY DEAR DEYE DREM SEX  \
# 0  62.0   16   1   17   1   0   1   1   4   2        1    2    2    2   2
# 1  48.0   21   1    0   2   0   1   1   4   2        1    2    2    2   2
# 2  47.0   21   1    1   2   0   1   1   4   4        1    2    2    2   1
# 3  34.0   12   5    0   2   0   1   3   4   1        1    2    2    2   1
# 4  33.0   23   5    0   2   0   5   1   4   1        2    2    2    2   1
#
#   RAC1P  employed  year  prediction  predicted_probability
# 0     1         0  2015           0               0.121211
# 1     1         0  2015           1               0.816033
# 2     1         0  2015           1               0.951815
# 3     2         0  2015           1               0.563825
# 4     1         1  2015           1               0.944436
#    AGEP SCHL MAR RELP DIS ESP CIT MIG MIL ANC NATIVITY DEAR DEYE DREM SEX  \
# 0  46.0   21   1    0   2   0   3   1   4   2        1    2    2    2   1
# 1  46.0   21   1    1   2   0   1   1   4   1        1    2    2    2   2
# 2  12.0    9   5    2   2   1   1   1   0   2        1    2    2    2   2
# 3  52.0   21   3    0   2   0   1   1   4   2        1    2    2    2   2
# 4  21.0   18   5    2   2   0   1   1   4   2        1    2    2    2   1
#
#   RAC1P  year  prediction  predicted_probability
# 0     1  2016           1               0.948828
# 1     1  2016           1               0.772002
# 2     1  2016           0               0.000149
# 3     1  2016           1               0.906070
# 4     1  2016           1               0.699663

# %%
print_some_of_the_columns_only_markdown(reference_df, 2, 5)
# Out:
# +----+--------+--------+-------+---------+------------+--------+--------------+-------------------------+
# |    | AGEP   | SCHL   | ...   | RAC1P   | employed   | year   | prediction   | predicted_probability   |
# +====+========+========+=======+=========+============+========+==============+=========================+
# | 0  | 62     | 16     | ...   | 1       | 0          | 2015   | 0            | 0.121211                |
# +----+--------+--------+-------+---------+------------+--------+--------------+-------------------------+
# | 1  | 48     | 21     | ...   | 1       | 0          | 2015   | 1            | 0.816033                |
# +----+--------+--------+-------+---------+------------+--------+--------------+-------------------------+
# | 2  | 47     | 21     | ...   | 1       | 0          | 2015   | 1            | 0.951815                |
# +----+--------+--------+-------+---------+------------+--------+--------------+-------------------------+
# | 3  | 34     | 12     | ...   | 2       | 0          | 2015   | 1            | 0.563825                |
# +----+--------+--------+-------+---------+------------+--------+--------------+-------------------------+
# | 4  | 33     | 23     | ...   | 1       | 1          | 2015   | 1            | 0.944436                |
# +----+--------+--------+-------+---------+------------+--------+--------------+-------------------------+

# %%
print_some_of_the_columns_only_markdown(analysis_df, 2, 5)
# Out:
# +----+--------+--------+-------+-------+---------+--------+--------------+-------------------------+
# |    | AGEP   | SCHL   | ...   | SEX   | RAC1P   | year   | prediction   | predicted_probability   |
# +====+========+========+=======+=======+=========+========+==============+=========================+
# | 0  | 46     | 21     | ...   | 1     | 1       | 2016   | 1            | 0.948828                |
# +----+--------+--------+-------+-------+---------+--------+--------------+-------------------------+
# | 1  | 46     | 21     | ...   | 2     | 1       | 2016   | 1            | 0.772002                |
# +----+--------+--------+-------+-------+---------+--------+--------------+-------------------------+
# | 2  | 12     | 9      | ...   | 2     | 1       | 2016   | 0            | 0.000149194             |
# +----+--------+--------+-------+-------+---------+--------+--------------+-------------------------+
# | 3  | 52     | 21     | ...   | 2     | 1       | 2016   | 1            | 0.90607                 |
# +----+--------+--------+-------+-------+---------+--------+--------------+-------------------------+
# | 4  | 21     | 18     | ...   | 1     | 1       | 2016   | 1            | 0.699663                |
# +----+--------+--------+-------+-------+---------+--------+--------------+-------------------------+

# %%
chunk_size = 5000

# %%
estimator = nml.CBPE(
    problem_type='classification_binary',
    y_pred_proba='predicted_probability',
    y_pred='prediction',
    y_true='employed',
    metrics=['roc_auc'],
    chunk_size=chunk_size,
)

# %%
estimator = estimator.fit(reference_df)
estimated_performance = estimator.estimate(analysis_df)
# Out:
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")
# /home/niels/Code/nml/nannyml/nannyml/performance_estimation/confidence_based/metrics.py:406: UserWarning: No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.
#   warnings.warn("No 'y_true' values given for chunk, returning NaN as realized ROC-AUC.")

# %%
figure = estimated_performance.plot()
figure.show()

# %%
figure.write_image('../_static/quickstart/quick-start-perf-est.svg', width=1000)

# %%
feature_column_names = ['AGEP', 'SCHL', 'MAR', 'RELP', 'DIS', 'ESP', 'CIT', 'MIG',
                        'MIL', 'ANC', 'NATIVITY', 'DEAR', 'DEYE', 'DREM', 'SEX', 'RAC1P']

univariate_calculator = nml.UnivariateDriftCalculator(
    column_names=feature_column_names,
    chunk_size=chunk_size
)

univariate_calculator.fit(reference_df)
univariate_drift = univariate_calculator.calculate(analysis_df)
# Out:
# error uploading: HTTPSConnectionPool(host='api.segment.io', port=443): Max retries exceeded with url: /v1/batch (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faff7ff5370>: Failed to establish a new connection: [Errno 111] Connection refused'))
# error uploading: HTTPSConnectionPool(host='api.segment.io', port=443): Max retries exceeded with url: /v1/batch (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faff7d768e0>: Failed to establish a new connection: [Errno 111] Connection refused'))

# %%
alert_count_ranker = nml.AlertCountRanker()
alert_count_ranked_features = alert_count_ranker.rank(univariate_drift)
display(alert_count_ranked_features.head())
# Out:
#    number_of_alerts column_name  rank
# 0                27        RELP     1
# 1                14        AGEP     2
# 2                 2        SCHL     3
# 3                 2         MIL     4
# 4                 2         MIG     5

# %%
print_table(alert_count_ranked_features.head())
# Out:
# +----+--------------------+---------------+--------+
# |    | number_of_alerts   | column_name   | rank   |
# +====+====================+===============+========+
# | 0  | 27                 | RELP          | 1      |
# +----+--------------------+---------------+--------+
# | 1  | 14                 | AGEP          | 2      |
# +----+--------------------+---------------+--------+
# | 2  | 2                  | SCHL          | 3      |
# +----+--------------------+---------------+--------+
# | 3  | 2                  | MIL           | 4      |
# +----+--------------------+---------------+--------+
# | 4  | 2                  | MIG           | 5      |
# +----+--------------------+---------------+--------+

# %%
figure = univariate_drift.filter(column_names=['RELP','AGEP', 'SCHL']).plot()
figure.show()

# %%
figure.write_image(f'../_static/quickstart/quick-start-drift.svg', width=1000)

# %%
uni_drift_AGEP_analysis = univariate_drift.filter(column_names=['AGEP'], period='analysis')
figure = estimated_performance.compare(uni_drift_AGEP_analysis).plot()
figure.show()

# %%
figure.write_image(f'../_static/quickstart/quick-start-drift-n-performance.svg', width=1000)

# %%
figure = univariate_drift.filter(period='analysis', column_names=['RELP','AGEP', 'SCHL']).plot(kind='distribution')
figure.show()

# %%
figure.write_image(f'../_static/quickstart/quick-start-univariate-distribution.svg', width=1000)
# Out:
# error uploading: HTTPSConnectionPool(host='api.segment.io', port=443): Max retries exceeded with url: /v1/batch (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faff7e76430>: Failed to establish a new connection: [Errno 111] Connection refused'))

# %%
_, _, analysis_targets_df = nml.load_us_census_ma_employment_data()

# %%
analysis_with_targets_df = pd.concat([analysis_df, analysis_targets_df], axis=1)
display(analysis_with_targets_df.head())
# Out:
#    AGEP SCHL MAR RELP DIS ESP CIT MIG MIL ANC NATIVITY DEAR DEYE DREM SEX  \
# 0  46.0   21   1    0   2   0   3   1   4   2        1    2    2    2   1
# 1  46.0   21   1    1   2   0   1   1   4   1        1    2    2    2   2
# 2  12.0    9   5    2   2   1   1   1   0   2        1    2    2    2   2
# 3  52.0   21   3    0   2   0   1   1   4   2        1    2    2    2   2
# 4  21.0   18   5    2   2   0   1   1   4   2        1    2    2    2   1
#
#   RAC1P  year  prediction  predicted_probability  employed
# 0     1  2016           1               0.948828         1
# 1     1  2016           1               0.772002         1
# 2     1  2016           0               0.000149         0
# 3     1  2016           1               0.906070         1
# 4     1  2016           1               0.699663         0

# %%
print_some_of_the_columns_only_markdown(analysis_with_targets_df.head(), 2, 5)
# Out:
# +----+--------+--------+-------+---------+--------+--------------+-------------------------+------------+
# |    | AGEP   | SCHL   | ...   | RAC1P   | year   | prediction   | predicted_probability   | employed   |
# +====+========+========+=======+=========+========+==============+=========================+============+
# | 0  | 46     | 21     | ...   | 1       | 2016   | 1            | 0.948828                | 1          |
# +----+--------+--------+-------+---------+--------+--------------+-------------------------+------------+
# | 1  | 46     | 21     | ...   | 1       | 2016   | 1            | 0.772002                | 1          |
# +----+--------+--------+-------+---------+--------+--------------+-------------------------+------------+
# | 2  | 12     | 9      | ...   | 1       | 2016   | 0            | 0.000149194             | 0          |
# +----+--------+--------+-------+---------+--------+--------------+-------------------------+------------+
# | 3  | 52     | 21     | ...   | 1       | 2016   | 1            | 0.90607                 | 1          |
# +----+--------+--------+-------+---------+--------+--------------+-------------------------+------------+
# | 4  | 21     | 18     | ...   | 1       | 2016   | 1            | 0.699663                | 0          |
# +----+--------+--------+-------+---------+--------+--------------+-------------------------+------------+

# %%
performance_calculator = nml.PerformanceCalculator(
    problem_type='classification_binary',
    y_pred_proba='predicted_probability',
    y_pred='prediction',
    y_true='employed',
    metrics=['roc_auc'],
    chunk_size=chunk_size)

performance_calculator.fit(reference_df)
calculated_performance = performance_calculator.calculate(analysis_with_targets_df)

figure = estimated_performance.filter(period='analysis').compare(calculated_performance).plot()
figure.show()

# %%
figure.write_image(f'../_static/quickstart/quick-start-estimated-and-realized.svg', width=1000)
