# %%
import pandas as pd

# %%
data = ['timestamp', 'features', 'y_pred_proba', 'y_pred', 'y_true']
pest = [
    'Required (reference and analysis)', '',
    'Required (reference and analysis)', 'Required (reference and analysis) Not needed for ROC_AUC metric',
    'Required (reference only)'
]

rperf = [
    'Required (reference and analysis)', '', '',
    'Required (reference and analysis) Not needed for ROC_AUC metric', 'Required (reference and analysis)'
]
univm = [
    'Required (reference and analysis)', 'Required (reference and analysis)',
    '', '', ''
]

trgt = [
    'Required (reference and analysis)', '', '', '', 'Required (reference and analysis)'
]

outp = [
    'Required (reference and analysis)', '', 'Required (reference and analysis)', 'Required (reference and analysis)', ''
]

# %%
required = pd.DataFrame({
    'Data': data,
    'Performance Estimation': pest,
    'Realized Performance': rperf,
    'Univariate Feature Drift': univm,
    'Multivariate Feature Drift': univm,
    'Target Drift': trgt,
    'Output Drift': outp
})
required
# Out:
#            Data                             Performance Estimation  \
# 0     timestamp                  Required (reference and analysis)
# 1      features
# 2  y_pred_proba                  Required (reference and analysis)
# 3        y_pred  Required (reference and analysis) Not needed f...
# 4        y_true                          Required (reference only)
#
#                                 Realized Performance  \
# 0                  Required (reference and analysis)
# 1
# 2
# 3  Required (reference and analysis) Not needed f...
# 4                  Required (reference and analysis)
#
#             Univariate Feature Drift         Multivariate Feature Drift  \
# 0  Required (reference and analysis)  Required (reference and analysis)
# 1  Required (reference and analysis)  Required (reference and analysis)
# 2
# 3
# 4
#
#                         Target Drift                       Output Drift
# 0  Required (reference and analysis)  Required (reference and analysis)
# 1
# ...

# %%
print(required.to_markdown(tablefmt='grid'))
# Out:
# +----+--------------+-----------------------------------------------------------------+-----------------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |    | Data         | Performance Estimation                                          | Realized Performance                                            | Univariate Feature Drift          | Multivariate Feature Drift        | Target Drift                      | Output Drift                      |
# +====+==============+=================================================================+=================================================================+===================================+===================================+===================================+===================================+
# ...
