# %%
import nannyml as nml
from IPython.display import display

reference_df, analysis_df, _ = nml.load_synthetic_multiclass_classification_dataset()

display(reference_df.head(3))
# Out:
#    id acq_channel  app_behavioral_score  requested_credit_limit app_channel  \
# 0   0    Partner3              1.808232                     350         web
# 1   1    Partner2              4.382568                     500      mobile
# 2   2    Partner2             -0.787575                     400         web
#
#    credit_bureau_score  stated_income  is_customer            timestamp  \
# 0                  309          15000         True  2020-05-02 02:01:30
# 1                  418          23000         True  2020-05-02 02:03:33
# 2                  507          24000        False  2020-05-02 02:04:49
#
#    y_pred_proba_prepaid_card  y_pred_proba_highstreet_card  \
# 0                       0.97                          0.03
# 1                       0.87                          0.13
# 2                       0.47                          0.35
#
#    y_pred_proba_upmarket_card        y_pred         y_true
# 0                        0.00  prepaid_card   prepaid_card
# 1                        0.00  prepaid_card   prepaid_card
# 2                        0.18  prepaid_card  upmarket_card

# %%
print(reference_df.head(3).to_markdown(tablefmt="grid"))
# Out:
# +----+------+---------------+------------------------+--------------------------+---------------+-----------------------+-----------------+---------------+---------------------+-----------------------------+--------------------------------+------------------------------+--------------+---------------+
# |    |   id | acq_channel   |   app_behavioral_score |   requested_credit_limit | app_channel   |   credit_bureau_score |   stated_income | is_customer   | timestamp           |   y_pred_proba_prepaid_card |   y_pred_proba_highstreet_card |   y_pred_proba_upmarket_card | y_pred       | y_true        |
# +====+======+===============+========================+==========================+===============+=======================+=================+===============+=====================+=============================+================================+==============================+==============+===============+
# |  0 |    0 | Partner3      |               1.80823  |                      350 | web           |                   309 |           15000 | True          | 2020-05-02 02:01:30 |                        0.97 |                           0.03 |                         0    | prepaid_card | prepaid_card  |
# +----+------+---------------+------------------------+--------------------------+---------------+-----------------------+-----------------+---------------+---------------------+-----------------------------+--------------------------------+------------------------------+--------------+---------------+
# |  1 |    1 | Partner2      |               4.38257  |                      500 | mobile        |                   418 |           23000 | True          | 2020-05-02 02:03:33 |                        0.87 |                           0.13 |                         0    | prepaid_card | prepaid_card  |
# +----+------+---------------+------------------------+--------------------------+---------------+-----------------------+-----------------+---------------+---------------------+-----------------------------+--------------------------------+------------------------------+--------------+---------------+
# |  2 |    2 | Partner2      |              -0.787575 |                      400 | web           |                   507 |           24000 | False         | 2020-05-02 02:04:49 |                        0.47 |                           0.35 |                         0.18 | prepaid_card | upmarket_card |
# +----+------+---------------+------------------------+--------------------------+---------------+-----------------------+-----------------+---------------+---------------------+-----------------------------+--------------------------------+------------------------------+--------------+---------------+

# %%
estimator = nml.IW(
    feature_column_names=[
            "app_behavioral_score",
            "requested_credit_limit",
            "credit_bureau_score",
            "stated_income",
            "acq_channel",
            "app_channel",
            "is_customer"
        ],
    y_pred_proba={
        'prepaid_card': 'y_pred_proba_prepaid_card',
        'highstreet_card': 'y_pred_proba_highstreet_card',
        'upmarket_card': 'y_pred_proba_upmarket_card'},
    y_pred='y_pred',
    y_true='y_true',
    timestamp_column_name='timestamp',
    problem_type='classification_multiclass',
    metrics=['roc_auc', 'f1'],
    chunk_size=6000,
)
estimator.fit(reference_df)

# %%
results = estimator.estimate(analysis_df)
display(results.filter(period='analysis').to_df())
# Out:
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1446: UserWarning: No 'y_true' values given for chunk, returning NaN as realized roc_auc.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1519: UserWarning: No 'y_true' values given for chunk, returning NaN as realized f1.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1446: UserWarning: No 'y_true' values given for chunk, returning NaN as realized roc_auc.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1519: UserWarning: No 'y_true' values given for chunk, returning NaN as realized f1.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1446: UserWarning: No 'y_true' values given for chunk, returning NaN as realized roc_auc.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1519: UserWarning: No 'y_true' values given for chunk, returning NaN as realized f1.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1446: UserWarning: No 'y_true' values given for chunk, returning NaN as realized roc_auc.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1519: UserWarning: No 'y_true' values given for chunk, returning NaN as realized f1.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1446: UserWarning: No 'y_true' values given for chunk, returning NaN as realized roc_auc.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1519: UserWarning: No 'y_true' values given for chunk, returning NaN as realized f1.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1446: UserWarning: No 'y_true' values given for chunk, returning NaN as realized roc_auc.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1519: UserWarning: No 'y_true' values given for chunk, returning NaN as realized f1.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1446: UserWarning: No 'y_true' values given for chunk, returning NaN as realized roc_auc.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1519: UserWarning: No 'y_true' values given for chunk, returning NaN as realized f1.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1446: UserWarning: No 'y_true' values given for chunk, returning NaN as realized roc_auc.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1519: UserWarning: No 'y_true' values given for chunk, returning NaN as realized f1.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1446: UserWarning: No 'y_true' values given for chunk, returning NaN as realized roc_auc.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1519: UserWarning: No 'y_true' values given for chunk, returning NaN as realized f1.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1446: UserWarning: No 'y_true' values given for chunk, returning NaN as realized roc_auc.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
# /var/home/nikml/Source/nannyml/nannyml/performance_estimation/importance_weighting/metrics.py:1519: UserWarning: No 'y_true' values given for chunk, returning NaN as realized f1.
#   warnings.warn(f"No 'y_true' values given for chunk, returning NaN as realized {self.name}.")
#            chunk                                                        \
#              key chunk_index start_index end_index          start_date
# 0       [0:5999]           0           0      5999 2020-09-01 03:10:01
# 1   [6000:11999]           1        6000     11999 2020-09-13 16:15:32
# 2  [12000:17999]           2       12000     17999 2020-09-25 19:50:04
# 3  [18000:23999]           3       18000     23999 2020-10-08 02:57:34
# 4  [24000:29999]           4       24000     29999 2020-10-20 15:49:06
# 5  [30000:35999]           5       30000     35999 2020-11-01 22:04:59
# 6  [36000:41999]           6       36000     41999 2020-11-14 03:55:49
# 7  [42000:47999]           7       42000     47999 2020-11-26 09:19:22
# 8  [48000:53999]           8       48000     53999 2020-12-08 14:34:25
# 9  [54000:59999]           9       54000     59999 2020-12-20 18:31:09
#
#                                   roc_auc                          ...  \
#              end_date    period     value sampling_error realized  ...
# 0 2020-09-13 16:15:10  analysis  0.905944       0.002143      NaN  ...
# 1 2020-09-25 19:48:42  analysis  0.907523       0.002143      NaN  ...
# 2 2020-10-08 02:53:47  analysis  0.907752       0.002143      NaN  ...
# 3 2020-10-20 15:48:19  analysis  0.906760       0.002143      NaN  ...
# 4 2020-11-01 22:04:40  analysis  0.906954       0.002143      NaN  ...
# 5 2020-11-14 03:55:33  analysis  0.778854       0.002143      NaN  ...
# 6 2020-11-26 09:19:06  analysis  0.785352       0.002143      NaN  ...
# 7 2020-12-08 14:33:56  analysis  0.791718       0.002143      NaN  ...
# 8 2020-12-20 18:30:30  analysis  0.783452       0.002143      NaN  ...
# 9 2021-01-01 22:57:55  analysis  0.790811       0.002143      NaN  ...
#
#                                 f1                          \
#   lower_threshold  alert     value sampling_error realized
# 0        0.900902  False  0.751333       0.005652      NaN
# 1        0.900902  False  0.753726       0.005652      NaN
# 2        0.900902  False  0.753968       0.005652      NaN
# 3        0.900902  False  0.752325       0.005652      NaN
# 4        0.900902  False  0.753075       0.005652      NaN
# 5        0.900902   True  0.587085       0.005652      NaN
# 6        0.900902   True  0.594210       0.005652      NaN
# 7        0.900902   True  0.598204       0.005652      NaN
# 8        0.900902   True  0.591153       0.005652      NaN
# 9        0.900902   True  0.596840       0.005652      NaN
#
#                                                                        \
#   upper_confidence_boundary lower_confidence_boundary upper_threshold
# 0                  0.768290                  0.734376        0.764944
# 1                  0.770682                  0.736769        0.764944
# 2                  0.770925                  0.737011        0.764944
# 3                  0.769282                  0.735368        0.764944
# 4                  0.770032                  0.736118        0.764944
# 5                  0.604042                  0.570128        0.764944
# 6                  0.611167                  0.577253        0.764944
# 7                  0.615161                  0.581247        0.764944
# 8                  0.608110                  0.574196        0.764944
# 9                  0.613797                  0.579883        0.764944
#
#
#   lower_threshold  alert
# 0        0.741254  False
# 1        0.741254  False
# 2        0.741254  False
# 3        0.741254  False
# 4        0.741254  False
# 5        0.741254   True
# 6        0.741254   True
# 7        0.741254   True
# 8        0.741254   True
# 9        0.741254   True
#
# [10 rows x 23 columns]

# %%
from docs.utils import print_multi_index_markdown
print_multi_index_markdown(results.filter(period='analysis').to_df())
# Out:
# +----+---------------+-----------------+-----------------+---------------+---------------------+---------------------+------------+-------------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+-----------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+
# |    | | chunk       |                 |                 |               |                     |                     |            | | roc_auc   |                    |              |                               |                               |                     |                     |           | | f1      |                    |              |                               |                               |                     |                     |           |
# |    | | key         | | chunk_index   | | start_index   | | end_index   | | start_date        | | end_date          | | period   | | value     | | sampling_error   | | realized   | | upper_confidence_boundary   | | lower_confidence_boundary   | | upper_threshold   | | lower_threshold   | | alert   | | value   | | sampling_error   | | realized   | | upper_confidence_boundary   | | lower_confidence_boundary   | | upper_threshold   | | lower_threshold   | | alert   |
# +====+===============+=================+=================+===============+=====================+=====================+============+=============+====================+==============+===============================+===============================+=====================+=====================+===========+===========+====================+==============+===============================+===============================+=====================+=====================+===========+
# | 0  | [0:5999]      | 0               | 0               | 5999          | 2020-09-01 03:10:01 | 2020-09-13 16:15:10 | analysis   | 0.905944    | 0.00214318         | nan          | 0.912373                      | 0.899514                      | 0.913516            | 0.900902            | False     | 0.751333  | 0.00565227         | nan          | 0.76829                       | 0.734376                      | 0.764944            | 0.741254            | False     |
# +----+---------------+-----------------+-----------------+---------------+---------------------+---------------------+------------+-------------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+-----------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+
# | 1  | [6000:11999]  | 1               | 6000            | 11999         | 2020-09-13 16:15:32 | 2020-09-25 19:48:42 | analysis   | 0.907523    | 0.00214318         | nan          | 0.913953                      | 0.901094                      | 0.913516            | 0.900902            | False     | 0.753726  | 0.00565227         | nan          | 0.770682                      | 0.736769                      | 0.764944            | 0.741254            | False     |
# +----+---------------+-----------------+-----------------+---------------+---------------------+---------------------+------------+-------------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+-----------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+
# | 2  | [12000:17999] | 2               | 12000           | 17999         | 2020-09-25 19:50:04 | 2020-10-08 02:53:47 | analysis   | 0.907752    | 0.00214318         | nan          | 0.914181                      | 0.901322                      | 0.913516            | 0.900902            | False     | 0.753968  | 0.00565227         | nan          | 0.770925                      | 0.737011                      | 0.764944            | 0.741254            | False     |
# +----+---------------+-----------------+-----------------+---------------+---------------------+---------------------+------------+-------------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+-----------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+
# | 3  | [18000:23999] | 3               | 18000           | 23999         | 2020-10-08 02:57:34 | 2020-10-20 15:48:19 | analysis   | 0.90676     | 0.00214318         | nan          | 0.913189                      | 0.90033                       | 0.913516            | 0.900902            | False     | 0.752325  | 0.00565227         | nan          | 0.769282                      | 0.735368                      | 0.764944            | 0.741254            | False     |
# +----+---------------+-----------------+-----------------+---------------+---------------------+---------------------+------------+-------------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+-----------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+
# | 4  | [24000:29999] | 4               | 24000           | 29999         | 2020-10-20 15:49:06 | 2020-11-01 22:04:40 | analysis   | 0.906954    | 0.00214318         | nan          | 0.913384                      | 0.900525                      | 0.913516            | 0.900902            | False     | 0.753075  | 0.00565227         | nan          | 0.770032                      | 0.736118                      | 0.764944            | 0.741254            | False     |
# +----+---------------+-----------------+-----------------+---------------+---------------------+---------------------+------------+-------------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+-----------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+
# | 5  | [30000:35999] | 5               | 30000           | 35999         | 2020-11-01 22:04:59 | 2020-11-14 03:55:33 | analysis   | 0.778854    | 0.00214318         | nan          | 0.785283                      | 0.772424                      | 0.913516            | 0.900902            | True      | 0.587085  | 0.00565227         | nan          | 0.604042                      | 0.570128                      | 0.764944            | 0.741254            | True      |
# +----+---------------+-----------------+-----------------+---------------+---------------------+---------------------+------------+-------------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+-----------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+
# | 6  | [36000:41999] | 6               | 36000           | 41999         | 2020-11-14 03:55:49 | 2020-11-26 09:19:06 | analysis   | 0.785352    | 0.00214318         | nan          | 0.791781                      | 0.778922                      | 0.913516            | 0.900902            | True      | 0.59421   | 0.00565227         | nan          | 0.611167                      | 0.577253                      | 0.764944            | 0.741254            | True      |
# +----+---------------+-----------------+-----------------+---------------+---------------------+---------------------+------------+-------------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+-----------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+
# | 7  | [42000:47999] | 7               | 42000           | 47999         | 2020-11-26 09:19:22 | 2020-12-08 14:33:56 | analysis   | 0.791718    | 0.00214318         | nan          | 0.798147                      | 0.785288                      | 0.913516            | 0.900902            | True      | 0.598204  | 0.00565227         | nan          | 0.615161                      | 0.581247                      | 0.764944            | 0.741254            | True      |
# +----+---------------+-----------------+-----------------+---------------+---------------------+---------------------+------------+-------------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+-----------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+
# | 8  | [48000:53999] | 8               | 48000           | 53999         | 2020-12-08 14:34:25 | 2020-12-20 18:30:30 | analysis   | 0.783452    | 0.00214318         | nan          | 0.789882                      | 0.777023                      | 0.913516            | 0.900902            | True      | 0.591153  | 0.00565227         | nan          | 0.60811                       | 0.574196                      | 0.764944            | 0.741254            | True      |
# +----+---------------+-----------------+-----------------+---------------+---------------------+---------------------+------------+-------------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+-----------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+
# | 9  | [54000:59999] | 9               | 54000           | 59999         | 2020-12-20 18:31:09 | 2021-01-01 22:57:55 | analysis   | 0.790811    | 0.00214318         | nan          | 0.797241                      | 0.784382                      | 0.913516            | 0.900902            | True      | 0.59684   | 0.00565227         | nan          | 0.613797                      | 0.579883                      | 0.764944            | 0.741254            | True      |
# +----+---------------+-----------------+-----------------+---------------+---------------------+---------------------+------------+-------------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+-----------+--------------------+--------------+-------------------------------+-------------------------------+---------------------+---------------------+-----------+

# %%
metric_fig = results.plot()
metric_fig.show()

# %%
metric_fig = results.plot()
metric_fig.write_image(file=f"../_static/tutorials/performance_estimation/multiclass/iw_standard_metrics.svg")
