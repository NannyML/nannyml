# %%
import nannyml as nml
from IPython.display import display

reference_df = nml.load_synthetic_multiclass_classification_dataset()[0]
analysis_df = nml.load_synthetic_multiclass_classification_dataset()[1]

display(reference_df.head())
# Out:
#   acq_channel  app_behavioral_score  requested_credit_limit app_channel  \
# 0    Partner3              1.808232                     350         web
# 1    Partner2              4.382568                     500      mobile
# 2    Partner2             -0.787575                     400         web
# 3    Partner3             -2.131770                     300      mobile
# 4    Partner3             -1.362938                     450      mobile
#
#    credit_bureau_score  stated_income  is_customer     period  identifier  \
# 0                  309          15000         True  reference       60000
# 1                  418          23000         True  reference       60001
# 2                  507          24000        False  reference       60002
# 3                  324          38000        False  reference       60003
# 4                  736          38000         True  reference       60004
#
#              timestamp  y_pred_proba_prepaid_card  \
# 0  2020-05-02 02:01:30                       0.97
# 1  2020-05-02 02:03:33                       0.87
# 2  2020-05-02 02:04:49                       0.47
# 3  2020-05-02 02:07:59                       0.26
# 4  2020-05-02 02:20:19                       0.03
#
#    y_pred_proba_highstreet_card  y_pred_proba_upmarket_card           y_pred  \
# 0                          0.03                        0.00     prepaid_card
# 1                          0.13                        0.00     prepaid_card
# 2                          0.35                        0.18     prepaid_card
# 3                          0.50                        0.24  highstreet_card
# 4                          0.04                        0.93    upmarket_card
#
#           y_true
# 0   prepaid_card
# 1   prepaid_card
# 2  upmarket_card
# 3  upmarket_card
# 4  upmarket_card

# %%
print(reference_df.head().to_markdown(tablefmt="grid"))
# Out:
# +----+---------------+------------------------+--------------------------+---------------+-----------------------+-----------------+---------------+-----------+--------------+---------------------+-----------------------------+--------------------------------+------------------------------+-----------------+---------------+
# |    | acq_channel   |   app_behavioral_score |   requested_credit_limit | app_channel   |   credit_bureau_score |   stated_income | is_customer   | period    |   identifier | timestamp           |   y_pred_proba_prepaid_card |   y_pred_proba_highstreet_card |   y_pred_proba_upmarket_card | y_pred          | y_true        |
# +====+===============+========================+==========================+===============+=======================+=================+===============+===========+==============+=====================+=============================+================================+==============================+=================+===============+
# |  0 | Partner3      |               1.80823  |                      350 | web           |                   309 |           15000 | True          | reference |        60000 | 2020-05-02 02:01:30 |                        0.97 |                           0.03 |                         0    | prepaid_card    | prepaid_card  |
# +----+---------------+------------------------+--------------------------+---------------+-----------------------+-----------------+---------------+-----------+--------------+---------------------+-----------------------------+--------------------------------+------------------------------+-----------------+---------------+
# |  1 | Partner2      |               4.38257  |                      500 | mobile        |                   418 |           23000 | True          | reference |        60001 | 2020-05-02 02:03:33 |                        0.87 |                           0.13 |                         0    | prepaid_card    | prepaid_card  |
# +----+---------------+------------------------+--------------------------+---------------+-----------------------+-----------------+---------------+-----------+--------------+---------------------+-----------------------------+--------------------------------+------------------------------+-----------------+---------------+
# |  2 | Partner2      |              -0.787575 |                      400 | web           |                   507 |           24000 | False         | reference |        60002 | 2020-05-02 02:04:49 |                        0.47 |                           0.35 |                         0.18 | prepaid_card    | upmarket_card |
# +----+---------------+------------------------+--------------------------+---------------+-----------------------+-----------------+---------------+-----------+--------------+---------------------+-----------------------------+--------------------------------+------------------------------+-----------------+---------------+
# |  3 | Partner3      |              -2.13177  |                      300 | mobile        |                   324 |           38000 | False         | reference |        60003 | 2020-05-02 02:07:59 |                        0.26 |                           0.5  |                         0.24 | highstreet_card | upmarket_card |
# +----+---------------+------------------------+--------------------------+---------------+-----------------------+-----------------+---------------+-----------+--------------+---------------------+-----------------------------+--------------------------------+------------------------------+-----------------+---------------+
# |  4 | Partner3      |              -1.36294  |                      450 | mobile        |                   736 |           38000 | True          | reference |        60004 | 2020-05-02 02:20:19 |                        0.03 |                           0.04 |                         0.93 | upmarket_card   | upmarket_card |
# +----+---------------+------------------------+--------------------------+---------------+-----------------------+-----------------+---------------+-----------+--------------+---------------------+-----------------------------+--------------------------------+------------------------------+-----------------+---------------+

# %%
calc = nml.StatisticalOutputDriftCalculator(
    y_pred='y_pred',
    y_pred_proba={
        'prepaid_card': 'y_pred_proba_prepaid_card',
        'upmarket_card': 'y_pred_proba_upmarket_card',
        'highstreet_card': 'y_pred_proba_highstreet_card'
    },
    timestamp_column_name='timestamp',
    problem_type='classification_multiclass')

calc.fit(reference_df)
results = calc.calculate(analysis_df)

# %%
display(results.data)
# Out:
#              key  start_index  end_index          start_date  \
# 0       [0:5999]            0       5999 2020-09-01 03:10:01
# 1   [6000:11999]         6000      11999 2020-09-13 16:15:32
# 2  [12000:17999]        12000      17999 2020-09-25 19:50:04
# 3  [18000:23999]        18000      23999 2020-10-08 02:57:34
# 4  [24000:29999]        24000      29999 2020-10-20 15:49:06
# 5  [30000:35999]        30000      35999 2020-11-01 22:04:59
# 6  [36000:41999]        36000      41999 2020-11-14 03:55:49
# 7  [42000:47999]        42000      47999 2020-11-26 09:19:22
# 8  [48000:53999]        48000      53999 2020-12-08 14:34:25
# 9  [54000:59999]        54000      59999 2020-12-20 18:31:09
#
#              end_date  y_pred_chi2  y_pred_p_value  y_pred_alert  \
# 0 2020-09-13 16:15:10     2.419913           0.298         False
# 1 2020-09-25 19:48:42     1.263388           0.532         False
# 2 2020-10-08 02:53:47     0.211705           0.900         False
# 3 2020-10-20 15:48:19     1.045942           0.593         False
# 4 2020-11-01 22:04:40     2.891012           0.236         False
# 5 2020-11-14 03:55:33   131.237909           0.000          True
# 6 2020-11-26 09:19:06   155.593054           0.000          True
# 7 2020-12-08 14:33:56   182.000637           0.000          True
# 8 2020-12-20 18:30:30   137.685269           0.000          True
# 9 2021-01-01 22:57:55   164.406677           0.000          True
#
#    y_pred_threshold  y_pred_proba_prepaid_card_dstat  ...  \
# 0              0.05                         0.013367  ...
# 1              0.05                         0.022033  ...
# 2              0.05                         0.009317  ...
# 3              0.05                         0.006800  ...
# 4              0.05                         0.016133  ...
# 5              0.05                         0.174467  ...
# 6              0.05                         0.171300  ...
# 7              0.05                         0.170533  ...
# 8              0.05                         0.173467  ...
# 9              0.05                         0.167300  ...
#
#    y_pred_proba_prepaid_card_alert  y_pred_proba_prepaid_card_threshold  \
# 0                            False                                 0.05
# 1                             True                                 0.05
# 2                            False                                 0.05
# 3                            False                                 0.05
# 4                            False                                 0.05
# 5                             True                                 0.05
# 6                             True                                 0.05
# 7                             True                                 0.05
# 8                             True                                 0.05
# 9                             True                                 0.05
#
#    y_pred_proba_upmarket_card_dstat  y_pred_proba_upmarket_card_p_value  \
# 0                          0.012283                               0.380
# 1                          0.008450                               0.828
# 2                          0.007867                               0.886
# 3                          0.012617                               0.347
# 4                          0.012617                               0.347
# 5                          0.146800                               0.000
# 6                          0.144717                               0.000
# 7                          0.140967                               0.000
# 8                          0.142050                               0.000
# 9                          0.147550                               0.000
#
#    y_pred_proba_upmarket_card_alert  y_pred_proba_upmarket_card_threshold  \
# 0                             False                                  0.05
# 1                             False                                  0.05
# 2                             False                                  0.05
# 3                             False                                  0.05
# 4                             False                                  0.05
# 5                              True                                  0.05
# 6                              True                                  0.05
# 7                              True                                  0.05
# 8                              True                                  0.05
# 9                              True                                  0.05
#
#    y_pred_proba_highstreet_card_dstat  y_pred_proba_highstreet_card_p_value  \
# 0                            0.005700                                 0.994
# 1                            0.013567                                 0.265
# 2                            0.008450                                 0.828
# 3                            0.020250                                 0.022
# 4                            0.010250                                 0.612
# 5                            0.207700                                 0.000
# 6                            0.210867                                 0.000
# 7                            0.215300                                 0.000
# 8                            0.209533                                 0.000
# 9                            0.205050                                 0.000
#
#    y_pred_proba_highstreet_card_alert  y_pred_proba_highstreet_card_threshold
# 0                               False                                    0.05
# 1                               False                                    0.05
# 2                               False                                    0.05
# 3                                True                                    0.05
# 4                               False                                    0.05
# 5                                True                                    0.05
# 6                                True                                    0.05
# 7                                True                                    0.05
# 8                                True                                    0.05
# 9                                True                                    0.05
#
# [10 rows x 21 columns]

# %%
print(results.data.to_markdown(tablefmt="grid"))
# Out:
# +----+---------------+---------------+-------------+---------------------+---------------------+---------------+------------------+----------------+--------------------+-----------------------------------+-------------------------------------+-----------------------------------+---------------------------------------+------------------------------------+--------------------------------------+------------------------------------+----------------------------------------+--------------------------------------+----------------------------------------+--------------------------------------+------------------------------------------+
# |    | key           |   start_index |   end_index | start_date          | end_date            |   y_pred_chi2 |   y_pred_p_value | y_pred_alert   |   y_pred_threshold |   y_pred_proba_prepaid_card_dstat |   y_pred_proba_prepaid_card_p_value | y_pred_proba_prepaid_card_alert   |   y_pred_proba_prepaid_card_threshold |   y_pred_proba_upmarket_card_dstat |   y_pred_proba_upmarket_card_p_value | y_pred_proba_upmarket_card_alert   |   y_pred_proba_upmarket_card_threshold |   y_pred_proba_highstreet_card_dstat |   y_pred_proba_highstreet_card_p_value | y_pred_proba_highstreet_card_alert   |   y_pred_proba_highstreet_card_threshold |
# +====+===============+===============+=============+=====================+=====================+===============+==================+================+====================+===================================+=====================================+===================================+=======================================+====================================+======================================+====================================+========================================+======================================+========================================+======================================+==========================================+
# |  0 | [0:5999]      |             0 |        5999 | 2020-09-01 03:10:01 | 2020-09-13 16:15:10 |      2.41991  |            0.298 | False          |               0.05 |                        0.0133667  |                               0.281 | False                             |                                  0.05 |                         0.0122833  |                                0.38  | False                              |                                   0.05 |                            0.0057    |                                  0.994 | False                                |                                     0.05 |
# +----+---------------+---------------+-------------+---------------------+---------------------+---------------+------------------+----------------+--------------------+-----------------------------------+-------------------------------------+-----------------------------------+---------------------------------------+------------------------------------+--------------------------------------+------------------------------------+----------------------------------------+--------------------------------------+----------------------------------------+--------------------------------------+------------------------------------------+
# |  1 | [6000:11999]  |          6000 |       11999 | 2020-09-13 16:15:32 | 2020-09-25 19:48:42 |      1.26339  |            0.532 | False          |               0.05 |                        0.0220333  |                               0.01  | True                              |                                  0.05 |                         0.00845    |                                0.828 | False                              |                                   0.05 |                            0.0135667 |                                  0.265 | False                                |                                     0.05 |
# +----+---------------+---------------+-------------+---------------------+---------------------+---------------+------------------+----------------+--------------------+-----------------------------------+-------------------------------------+-----------------------------------+---------------------------------------+------------------------------------+--------------------------------------+------------------------------------+----------------------------------------+--------------------------------------+----------------------------------------+--------------------------------------+------------------------------------------+
# |  2 | [12000:17999] |         12000 |       17999 | 2020-09-25 19:50:04 | 2020-10-08 02:53:47 |      0.211705 |            0.9   | False          |               0.05 |                        0.00931667 |                               0.727 | False                             |                                  0.05 |                         0.00786667 |                                0.886 | False                              |                                   0.05 |                            0.00845   |                                  0.828 | False                                |                                     0.05 |
# +----+---------------+---------------+-------------+---------------------+---------------------+---------------+------------------+----------------+--------------------+-----------------------------------+-------------------------------------+-----------------------------------+---------------------------------------+------------------------------------+--------------------------------------+------------------------------------+----------------------------------------+--------------------------------------+----------------------------------------+--------------------------------------+------------------------------------------+
# |  3 | [18000:23999] |         18000 |       23999 | 2020-10-08 02:57:34 | 2020-10-20 15:48:19 |      1.04594  |            0.593 | False          |               0.05 |                        0.0068     |                               0.961 | False                             |                                  0.05 |                         0.0126167  |                                0.347 | False                              |                                   0.05 |                            0.02025   |                                  0.022 | True                                 |                                     0.05 |
# +----+---------------+---------------+-------------+---------------------+---------------------+---------------+------------------+----------------+--------------------+-----------------------------------+-------------------------------------+-----------------------------------+---------------------------------------+------------------------------------+--------------------------------------+------------------------------------+----------------------------------------+--------------------------------------+----------------------------------------+--------------------------------------+------------------------------------------+
# |  4 | [24000:29999] |         24000 |       29999 | 2020-10-20 15:49:06 | 2020-11-01 22:04:40 |      2.89101  |            0.236 | False          |               0.05 |                        0.0161333  |                               0.116 | False                             |                                  0.05 |                         0.0126167  |                                0.347 | False                              |                                   0.05 |                            0.01025   |                                  0.612 | False                                |                                     0.05 |
# +----+---------------+---------------+-------------+---------------------+---------------------+---------------+------------------+----------------+--------------------+-----------------------------------+-------------------------------------+-----------------------------------+---------------------------------------+------------------------------------+--------------------------------------+------------------------------------+----------------------------------------+--------------------------------------+----------------------------------------+--------------------------------------+------------------------------------------+
# |  5 | [30000:35999] |         30000 |       35999 | 2020-11-01 22:04:59 | 2020-11-14 03:55:33 |    131.238    |            0     | True           |               0.05 |                        0.174467   |                               0     | True                              |                                  0.05 |                         0.1468     |                                0     | True                               |                                   0.05 |                            0.2077    |                                  0     | True                                 |                                     0.05 |
# +----+---------------+---------------+-------------+---------------------+---------------------+---------------+------------------+----------------+--------------------+-----------------------------------+-------------------------------------+-----------------------------------+---------------------------------------+------------------------------------+--------------------------------------+------------------------------------+----------------------------------------+--------------------------------------+----------------------------------------+--------------------------------------+------------------------------------------+
# |  6 | [36000:41999] |         36000 |       41999 | 2020-11-14 03:55:49 | 2020-11-26 09:19:06 |    155.593    |            0     | True           |               0.05 |                        0.1713     |                               0     | True                              |                                  0.05 |                         0.144717   |                                0     | True                               |                                   0.05 |                            0.210867  |                                  0     | True                                 |                                     0.05 |
# +----+---------------+---------------+-------------+---------------------+---------------------+---------------+------------------+----------------+--------------------+-----------------------------------+-------------------------------------+-----------------------------------+---------------------------------------+------------------------------------+--------------------------------------+------------------------------------+----------------------------------------+--------------------------------------+----------------------------------------+--------------------------------------+------------------------------------------+
# |  7 | [42000:47999] |         42000 |       47999 | 2020-11-26 09:19:22 | 2020-12-08 14:33:56 |    182.001    |            0     | True           |               0.05 |                        0.170533   |                               0     | True                              |                                  0.05 |                         0.140967   |                                0     | True                               |                                   0.05 |                            0.2153    |                                  0     | True                                 |                                     0.05 |
# +----+---------------+---------------+-------------+---------------------+---------------------+---------------+------------------+----------------+--------------------+-----------------------------------+-------------------------------------+-----------------------------------+---------------------------------------+------------------------------------+--------------------------------------+------------------------------------+----------------------------------------+--------------------------------------+----------------------------------------+--------------------------------------+------------------------------------------+
# |  8 | [48000:53999] |         48000 |       53999 | 2020-12-08 14:34:25 | 2020-12-20 18:30:30 |    137.685    |            0     | True           |               0.05 |                        0.173467   |                               0     | True                              |                                  0.05 |                         0.14205    |                                0     | True                               |                                   0.05 |                            0.209533  |                                  0     | True                                 |                                     0.05 |
# +----+---------------+---------------+-------------+---------------------+---------------------+---------------+------------------+----------------+--------------------+-----------------------------------+-------------------------------------+-----------------------------------+---------------------------------------+------------------------------------+--------------------------------------+------------------------------------+----------------------------------------+--------------------------------------+----------------------------------------+--------------------------------------+------------------------------------------+
# |  9 | [54000:59999] |         54000 |       59999 | 2020-12-20 18:31:09 | 2021-01-01 22:57:55 |    164.407    |            0     | True           |               0.05 |                        0.1673     |                               0     | True                              |                                  0.05 |                         0.14755    |                                0     | True                               |                                   0.05 |                            0.20505   |                                  0     | True                                 |                                     0.05 |
# +----+---------------+---------------+-------------+---------------------+---------------------+---------------+------------------+----------------+--------------------+-----------------------------------+-------------------------------------+-----------------------------------+---------------------------------------+------------------------------------+--------------------------------------+------------------------------------+----------------------------------------+--------------------------------------+----------------------------------------+--------------------------------------+------------------------------------------+

# %%
for label in calc.y_pred_proba.keys():
    figure = results.plot(kind='score_drift', class_label=label, plot_reference=True)
    figure.show()

# %%
for label in calc.y_pred_proba.keys():
    figure = results.plot(kind='score_drift', class_label=label, plot_reference=True)
    figure.write_image(f'../_static/tutorials/detecting_data_drift/model_outputs/multiclass/drift-guide-score-drift-{label}.svg')

# %%
for label in calc.y_pred_proba.keys():
    figure = results.plot(kind='score_distribution', class_label=label, plot_reference=True)
    figure.show()

# %%
for label in calc.y_pred_proba.keys():
    figure = results.plot(kind='score_distribution', class_label=label, plot_reference=True)
    figure.write_image(f'../_static/tutorials/detecting_data_drift/model_outputs/multiclass/drift-guide-score-distribution-{label}.svg')

# %%
figure = results.plot(kind='prediction_drift', plot_reference=True)
figure.show()

# %%
for label in calc.y_pred_proba.keys():
    figure = results.plot(kind='prediction_drift', class_label=label, plot_reference=True)
    figure.write_image(f'../_static/tutorials/detecting_data_drift/model_outputs/multiclass/drift-guide-prediction_drift-{label}.svg')

# %%
figure = results.plot(kind='prediction_distribution', plot_reference=True)
figure.show()

# %%
for label in calc.y_pred_proba.keys():
    figure = results.plot(kind='prediction_distribution', class_label=label, plot_reference=True)
    figure.write_image(f'../_static/tutorials/detecting_data_drift/model_outputs/multiclass/drift-guide-prediction-distribution-{label}.svg')
