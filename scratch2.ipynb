# %%
import nannyml as nml

ref_df, ana_df, _ = nml.load_synthetic_binary_classification_dataset()

cbpe = nml.CBPE(
    y_pred_proba='y_pred_proba',
    y_pred='y_pred',
    y_true='work_home_actual',
    problem_type='classification_binary',
    metrics=['confusion_matrix', 'roc_auc'],
    normalize_confusion_matrix=None,
    chunk_size=20_000,
)
cbpe.fit(ref_df)
result = cbpe.estimate(ana_df)
df = result.to_df()

df
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# /Users/carterblair/NannyMLdev/nannyml/nannyml/chunk.py:181: UserWarning: The resulting number of chunks is too low. Please consider splitting your data in a different way or continue at your own risk.
#   warnings.warn(
# /Users/carterblair/NannyMLdev/nannyml/nannyml/chunk.py:181: UserWarning: The resulting number of chunks is too low. Please consider splitting your data in a different way or continue at your own risk.
#   warnings.warn(
# /Users/carterblair/NannyMLdev/nannyml/nannyml/chunk.py:181: UserWarning: The resulting number of chunks is too low. Please consider splitting your data in a different way or continue at your own risk.
#   warnings.warn(
#            chunk                                                        \
# ...

# %%
import nannyml as nml

ref_df, ana_df, _ = nml.load_synthetic_multiclass_classification_dataset()

ref_df.head()

y_pred_proba_dict = {"prepaid_card": "y_pred_proba_prepaid_card", "highstreet_card": "y_pred_proba_highstreet_card", "upmarket_card": "y_pred_proba_upmarket_card"}

cbpe = nml.CBPE(
    y_pred_proba=y_pred_proba_dict,
    y_pred='y_pred',
    y_true='y_true',
    problem_type='classification_multiclass',
    metrics=['roc_auc', "f1", 'accuracy', 'specificity'],
    chunk_size=20_000,
)
cbpe.fit(ref_df)
result = cbpe.estimate(ana_df)
df = result.to_df()

df
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# /Users/carterblair/NannyMLdev/nannyml/nannyml/chunk.py:181: UserWarning: The resulting number of chunks is too low. Please consider splitting your data in a different way or continue at your own risk.
#   warnings.warn(
# /Users/carterblair/NannyMLdev/nannyml/nannyml/chunk.py:181: UserWarning: The resulting number of chunks is too low. Please consider splitting your data in a different way or continue at your own risk.
#   warnings.warn(
# /Users/carterblair/NannyMLdev/nannyml/nannyml/chunk.py:181: UserWarning: The resulting number of chunks is too low. Please consider splitting your data in a different way or continue at your own risk.
#   warnings.warn(
# ...

# %%
li = [1,2,3]
li2 = [4,5,6]

li.extend(li2)
li
# Out:
# [1, 2, 3, 4, 5, 6]
